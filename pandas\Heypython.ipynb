# %% [markdown]
# <a href="https://colab.research.google.com/github/zayuin1004/skills-introduction-to-github/blob/main/pandas%5CHeypython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("aa")
# Out:
# aa

# %%
import pandas as pd
